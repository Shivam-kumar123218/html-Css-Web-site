# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
data = pd.read_csv('/content/Balaji Fast Food Sales.csv')
data
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1    7/3/2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4    2/3/2023  Sugarcane juice  Beverages          25         6
# 4           5   10/2/2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
data.tail()
# Out:
#      order_id       date item_name item_type  item_price  quantity  \
# 995       996  3/19/2023   Frankie  Fastfood          50        10
# 996       997  9/20/2022  Sandwich  Fastfood          60         7
# 997       998  1/26/2023  Sandwich  Fastfood          60        13
# 998       999  8/27/2022  Panipuri  Fastfood          20         5
# 999      1000  5/29/2022  Aalopuri  Fastfood          20         3
#
#      transaction_amount transaction_type received_by time_of_sale
# 995                 500              NaN        Mrs.      Evening
# 996                 420              NaN         Mr.      Evening
# 997                 780              NaN         Mr.      Evening
# 998                 100              NaN        Mrs.    Afternoon
# 999                  60           Online        Mrs.     Midnight

# %%
data.head()
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1    7/3/2022         Aalopuri   Fastfood          20        13
# 1         2   8/23/2022          Vadapav   Fastfood          20        15
# 2         3  11/20/2022          Vadapav   Fastfood          20         1
# 3         4    2/3/2023  Sugarcane juice  Beverages          25         6
# 4         5   10/2/2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            1000 non-null   int64
#  1   date                1000 non-null   object
#  2   item_name           1000 non-null   object
#  3   item_type           1000 non-null   object
#  4   item_price          1000 non-null   int64
#  5   quantity            1000 non-null   int64
#  6   transaction_amount  1000 non-null   int64
#  7   transaction_type    893 non-null    object
#  8   received_by         1000 non-null   object
#  9   time_of_sale        1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB

# %%
data.isnull().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
data.describe()
# Out:
#           order_id   item_price     quantity  transaction_amount
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean    500.500000    33.315000     8.162000          275.230000
# std     288.819436    14.921744     4.413075          204.402979
# min       1.000000    20.000000     1.000000           20.000000
# 25%     250.750000    20.000000     4.000000          120.000000
# 50%     500.500000    25.000000     8.000000          240.000000
# 75%     750.250000    50.000000    12.000000          360.000000
# max    1000.000000    60.000000    15.000000          900.000000

# %%
data['transaction_type']=data['transaction_type'].fillna('Cash')
data.isnull().sum()
# Out:
# order_id              0
# date                  0
# item_name             0
# item_type             0
# item_price            0
# quantity              0
# transaction_amount    0
# transaction_type      0
# received_by           0
# time_of_sale          0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 10)

# %%
data.dtypes
# Out:
# order_id               int64
# date                  object
# item_name             object
# item_type             object
# item_price             int64
# quantity               int64
# transaction_amount     int64
# transaction_type      object
# received_by           object
# time_of_sale          object
# dtype: object

# %%
data.drop("order_id" , axis=1 , inplace=True, errors='ignore')

# %%
data.head()
# Out:
#          date        item_name  item_type  item_price  quantity  \
# 0    7/3/2022         Aalopuri   Fastfood          20        13
# 1   8/23/2022          Vadapav   Fastfood          20        15
# 2  11/20/2022          Vadapav   Fastfood          20         1
# 3    2/3/2023  Sugarcane juice  Beverages          25         6
# 4   10/2/2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260             Cash         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
data['item_type'].value_counts()
# Out:
# item_type
# Fastfood     686
# Beverages    314
# Name: count, dtype: int64

# %%
data['transaction_type'].value_counts()
# Out:
# transaction_type
# Cash      583
# Online    417
# Name: count, dtype: int64

# %%
data['time_of_sale'].value_counts()
# Out:
# time_of_sale
# Night        205
# Afternoon    205
# Evening      201
# Midnight     199
# Morning      190
# Name: count, dtype: int64

# %%
data['received_by'] = data['received_by'].replace({'Mr.': 'Male', 'Mrs.': 'Female'})
data
# Out:
#            date        item_name  item_type  item_price  quantity  \
# 0      7/3/2022         Aalopuri   Fastfood          20        13
# 1     8/23/2022          Vadapav   Fastfood          20        15
# 2    11/20/2022          Vadapav   Fastfood          20         1
# 3      2/3/2023  Sugarcane juice  Beverages          25         6
# 4     10/2/2022  Sugarcane juice  Beverages          25         8
# ..          ...              ...        ...         ...       ...
# 995   3/19/2023          Frankie   Fastfood          50        10
# 996   9/20/2022         Sandwich   Fastfood          60         7
# 997   1/26/2023         Sandwich   Fastfood          60        13
# 998   8/27/2022         Panipuri   Fastfood          20         5
# 999   5/29/2022         Aalopuri   Fastfood          20         3
#
#      transaction_amount transaction_type received_by time_of_sale
# 0                   260             Cash        Male        Night
# ...

# %%
data['received_by'].value_counts()
# Out:
# received_by
# Male      512
# Female    488
# Name: count, dtype: int64

# %%
data = data.rename(columns={'received_by': 'gender' ,'transaction_amount': 'transaction_₹' })
data
# Out:
#            date        item_name  item_type  item_price  quantity  \
# 0      7/3/2022         Aalopuri   Fastfood          20        13
# 1     8/23/2022          Vadapav   Fastfood          20        15
# 2    11/20/2022          Vadapav   Fastfood          20         1
# 3      2/3/2023  Sugarcane juice  Beverages          25         6
# 4     10/2/2022  Sugarcane juice  Beverages          25         8
# ..          ...              ...        ...         ...       ...
# 995   3/19/2023          Frankie   Fastfood          50        10
# 996   9/20/2022         Sandwich   Fastfood          60         7
# 997   1/26/2023         Sandwich   Fastfood          60        13
# 998   8/27/2022         Panipuri   Fastfood          20         5
# 999   5/29/2022         Aalopuri   Fastfood          20         3
#
#      transaction_₹ transaction_type  gender time_of_sale
# 0              260             Cash    Male        Night
# 1              300             Cash    Male    Afternoon
# ...

# %%
data.rename(columns={'gender': 'Sex'}, inplace=True)

# %%
data['transaction_₹'] = '₹' + data['transaction_₹'].astype(str)
data
# Out:
#            date        item_name  item_type  item_price  quantity  \
# 0      7/3/2022         Aalopuri   Fastfood          20        13
# 1     8/23/2022          Vadapav   Fastfood          20        15
# 2    11/20/2022          Vadapav   Fastfood          20         1
# 3      2/3/2023  Sugarcane juice  Beverages          25         6
# 4     10/2/2022  Sugarcane juice  Beverages          25         8
# ..          ...              ...        ...         ...       ...
# 995   3/19/2023          Frankie   Fastfood          50        10
# 996   9/20/2022         Sandwich   Fastfood          60         7
# 997   1/26/2023         Sandwich   Fastfood          60        13
# 998   8/27/2022         Panipuri   Fastfood          20         5
# 999   5/29/2022         Aalopuri   Fastfood          20         3
#
#     transaction_₹ transaction_type     Sex time_of_sale
# 0            ₹260             Cash    Male        Night
# 1            ₹300             Cash    Male    Afternoon
# ...

# %%
sns.countplot(x='item_type' , hue='Sex', data=data)
# Out:
# <Axes: xlabel='item_type', ylabel='count'>

# %%
data['transaction_₹'] = data['transaction_₹'].str.replace('₹', '', regex=False).astype(float)
sns.barplot(x='Sex' , y='transaction_₹' , data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='transaction_₹'>

# %%
sns.boxplot(x='item_type' , y='quantity' ,hue='Sex', data=data)
# Out:
# <Axes: xlabel='item_type', ylabel='quantity'>

# %%
plt.pie(data['Sex'].value_counts(), labels=data['Sex'].unique(), autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
plt.pie(data['transaction_type'].value_counts(), labels=data['transaction_type'].unique(), autopct='%1.1f%%')
plt.title('Item Type Distribution')
# Out:
# Text(0.5, 1.0, 'Item Type Distribution')

# %%
data.rename(columns={'date': 'Date'}, inplace=True)
data
# Out:
#            Date        item_name  item_type  item_price  quantity  \
# 0      7/3/2022         Aalopuri   Fastfood          20        13
# 1     8/23/2022          Vadapav   Fastfood          20        15
# 2    11/20/2022          Vadapav   Fastfood          20         1
# 3      2/3/2023  Sugarcane juice  Beverages          25         6
# 4     10/2/2022  Sugarcane juice  Beverages          25         8
# ..          ...              ...        ...         ...       ...
# 995   3/19/2023          Frankie   Fastfood          50        10
# 996   9/20/2022         Sandwich   Fastfood          60         7
# 997   1/26/2023         Sandwich   Fastfood          60        13
# 998   8/27/2022         Panipuri   Fastfood          20         5
# 999   5/29/2022         Aalopuri   Fastfood          20         3
#
#      transaction_₹ transaction_type     Sex time_of_sale
# 0            260.0             Cash    Male        Night
# 1            300.0             Cash    Male    Afternoon
# ...

# %%
data['quantity']. describe()
# Out:
# count    1000.000000
# mean        8.162000
# std         4.413075
# min         1.000000
# 25%         4.000000
# 50%         8.000000
# 75%        12.000000
# max        15.000000
# Name: quantity, dtype: float64

# %%
data['time_of_sale'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='time_of_sale'>

# %%
data['time_of_sale'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['item_type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data
# Out:
#            Date        item_name  item_type  item_price  quantity  \
# 0      7/3/2022         Aalopuri   Fastfood          20        13
# 1     8/23/2022          Vadapav   Fastfood          20        15
# 2    11/20/2022          Vadapav   Fastfood          20         1
# 3      2/3/2023  Sugarcane juice  Beverages          25         6
# 4     10/2/2022  Sugarcane juice  Beverages          25         8
# ..          ...              ...        ...         ...       ...
# 995   3/19/2023          Frankie   Fastfood          50        10
# 996   9/20/2022         Sandwich   Fastfood          60         7
# 997   1/26/2023         Sandwich   Fastfood          60        13
# 998   8/27/2022         Panipuri   Fastfood          20         5
# 999   5/29/2022         Aalopuri   Fastfood          20         3
#
#      transaction_₹ transaction_type     Sex time_of_sale
# 0            260.0             Cash    Male        Night
# 1            300.0             Cash    Male    Afternoon
# ...

# %%
pd.crosstab(data['Sex'], data['item_type'],normalize='columns')*100
# Out:
# item_type  Beverages   Fastfood
# Sex
# Female     48.726115  48.833819
# Male       51.273885  51.166181

# %%
pd.crosstab(data['Sex'], data['transaction_type'],normalize='columns')*100
# Out:
# transaction_type       Cash     Online
# Sex
# Female            47.855918  50.119904
# Male              52.144082  49.880096

# %%
pd.crosstab(data['Sex'], data['time_of_sale'],normalize='columns')*100
# Out:
# time_of_sale  Afternoon    Evening   Midnight    Morning      Night
# Sex
# Female        44.878049  47.761194  57.286432  47.368421  46.829268
# Male          55.121951  52.238806  42.713568  52.631579  53.170732

# %%
data[data['Sex']=='Male']['quantity'].plot(kind='kde',label='Male')
data[data['Sex']=='Female']['quantity'].plot(kind='kde',label='Female')
plt.legend()

# %%
data.iloc[50]
# Out:
# Date                5/16/2022
# item_name             Frankie
# item_type            Fastfood
# item_price                 50
# quantity                   15
# transaction_₹           750.0
# transaction_type       Online
# Sex                    Female
# time_of_sale          Morning
# Name: 50, dtype: object

# %%
data.loc[[122,566]]
# Out:
#            Date    item_name  item_type  item_price  quantity  transaction_₹  \
# 122    6/9/2022  Cold coffee  Beverages          40         6          240.0
# 566  10/16/2022  Cold coffee  Beverages          40         7          280.0
#
#     transaction_type     Sex time_of_sale
# 122           Online    Male      Evening
# 566           Online  Female    Afternoon

# %%
data[data['item_price'] > 50]
# Out:
#            Date item_name item_type  item_price  quantity  transaction_₹  \
# 15    4/14/2022  Sandwich  Fastfood          60        11          660.0
# 22    5/26/2022  Sandwich  Fastfood          60         3          180.0
# 24    8/31/2022  Sandwich  Fastfood          60         1           60.0
# 39     2/5/2023  Sandwich  Fastfood          60         5          300.0
# 46    7/10/2022  Sandwich  Fastfood          60         7          420.0
# ..          ...       ...       ...         ...       ...            ...
# 957   5/22/2022  Sandwich  Fastfood          60        11          660.0
# 990   1/18/2023  Sandwich  Fastfood          60         7          420.0
# 991  10/21/2022  Sandwich  Fastfood          60         5          300.0
# 996   9/20/2022  Sandwich  Fastfood          60         7          420.0
# 997   1/26/2023  Sandwich  Fastfood          60        13          780.0
#
#     transaction_type     Sex time_of_sale
# 15              Cash  Female     Midnight
# ...

# %%
data[data['transaction_₹'] == '₹60']
# Out:
# Empty DataFrame
# Columns: [Date, item_name, item_type, item_price, quantity, transaction_₹, transaction_type, Sex, time_of_sale]
# Index: []
