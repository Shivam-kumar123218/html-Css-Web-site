# %%
#Series data 
import numpy as np 
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_list = [10,20,30]
arr = np.array([100,200,300])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,index=d)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
pd.Series(my_list,index=d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,index=my_list)
# Out:
# 10    100
# 20    200
# 30    300
# dtype: int64
