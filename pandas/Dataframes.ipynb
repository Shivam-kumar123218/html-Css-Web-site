# %%
#Creating a DataFrame
import numpy as np
import pandas as pd

# %%
Data = {
    'Name':['shivam','sujeet','khemraj sir', 'vineeta'],
    'Age' :[18,16,40,36],
    'city':[ 'delhi','Mumbai','Goa','Dubai'],
    'Salary':[200000,1000000,25000,30000]
}
sh = pd.DataFrame(Data)

# %%
sh
# Out:
#           Name  Age    city   Salary
# 0       shivam   18   delhi   200000
# 1       sujeet   16  Mumbai  1000000
# 2  khemraj sir   40     Goa    25000
# 3      vineeta   36   Dubai    30000

# %%
data_list = [
['shivam',	18	,'delhi',	200000],
['sujeet',	16	,'Mumbai'	,1000000],
['khemraj sir',	40	,'Goa'	,25000],
['vineeta',	36	,'Dubai',	30000]
]

sh2 = pd.DataFrame(data_list)
columns = [ 'Name','Age','City','Salary']
sh2 = pd.DataFrame(data_list, columns=columns)
sh2
# Out:
#           Name  Age    City   Salary
# 0       shivam   18   delhi   200000
# 1       sujeet   16  Mumbai  1000000
# 2  khemraj sir   40     Goa    25000
# 3      vineeta   36   Dubai    30000

# %%
sh2
# Out:
#           Name  Age    City   Salary
# 0       shivam   18   delhi   200000
# 1       sujeet   16  Mumbai  1000000
# 2  khemraj sir   40     Goa    25000
# 3      vineeta   36   Dubai    30000

# %%
#Selection and Indexing of Columns
sh2
# Out:
#           Name  Age    City   Salary
# 0       shivam   18   delhi   200000
# 1       sujeet   16  Mumbai  1000000
# 2  khemraj sir   40     Goa    25000
# 3      vineeta   36   Dubai    30000

# %%
sh2[['Name','City']]
# Out:
#           Name    City
# 0       shivam   delhi
# 1       sujeet  Mumbai
# 2  khemraj sir     Goa
# 3      vineeta   Dubai

# %%
sh2[['Name','Salary']]
# Out:
#           Name   Salary
# 0       shivam   200000
# 1       sujeet  1000000
# 2  khemraj sir    25000
# 3      vineeta    30000

# %%
sh2[['Name', 'Age']]
# Out:
#           Name  Age
# 0       shivam   18
# 1       sujeet   16
# 2  khemraj sir   40
# 3      vineeta   36

# %%
#Creating a new column

# %%
sh2
# Out:
#           Name  Age    City   Salary
# 0       shivam   18   delhi   200000
# 1       sujeet   16  Mumbai  1000000
# 2  khemraj sir   40     Goa    25000
# 3      vineeta   36   Dubai    30000

# %%
sh2["Genger"] = ["male","male","male","female"]

# %%
sh2
# Out:
#           Name  Age    City   Salary  Genger
# 0       shivam   18   delhi   200000    male
# 1       sujeet   16  Mumbai  1000000    male
# 2  khemraj sir   40     Goa    25000    male
# 3      vineeta   36   Dubai    30000  female

# %%
#Removing Columns

# %%
sh2.drop(1,axis= 1)
# Out:
#           Name  Age    City   Salary  Genger
# 1       sujeet   16  Mumbai  1000000    male
# 2  khemraj sir   40     Goa    25000    male
# 3      vineeta   36   Dubai    30000  female

# %%
sh2
# Out:
#           Name  Age    City   Salary  Genger
# 0       shivam   18   delhi   200000    male
# 1       sujeet   16  Mumbai  1000000    male
# 2  khemraj sir   40     Goa    25000    male
# 3      vineeta   36   Dubai    30000  female

# %%
#Selecting Rows

# %%
sh2
# Out:
#           Name  Age    City   Salary  Genger
# 0       shivam   18   delhi   200000    male
# 1       sujeet   16  Mumbai  1000000    male
# 2  khemraj sir   40     Goa    25000    male
# 3      vineeta   36   Dubai    30000  female

# %%
sh2.loc[[2,3]]
# Out:
#           Name  Age   City  Salary  Genger
# 2  khemraj sir   40    Goa   25000    male
# 3      vineeta   36  Dubai   30000  female

# %%
sh2.loc[[0,3]]
# Out:
#       Name  Age   City  Salary  Genger
# 0   shivam   18  delhi  200000    male
# 3  vineeta   36  Dubai   30000  female

# %%
sh2
# Out:
#           Name  Age    City   Salary  Genger
# 0       shivam   18   delhi   200000    male
# 1       sujeet   16  Mumbai  1000000    male
# 2  khemraj sir   40     Goa    25000    male
# 3      vineeta   36   Dubai    30000  female

# %%
sh2.iloc[[2]]
# Out:
#           Name  Age City  Salary Genger
# 2  khemraj sir   40  Goa   25000   male

# %%
sh2.iloc[3]
# Out:
# Name      vineeta
# Age            36
# City        Dubai
# Salary      30000
# Genger     female
# Name: 3, dtype: object

# %%
sh2.iloc[1]
# Out:
# Name       sujeet
# Age            16
# City       Mumbai
# Salary    1000000
# Genger       male
# Name: 1, dtype: object

# %%
sh2
# Out:
#           Name  Age    City   Salary  Genger
# 0       shivam   18   delhi   200000    male
# 1       sujeet   16  Mumbai  1000000    male
# 2  khemraj sir   40     Goa    25000    male
# 3      vineeta   36   Dubai    30000  female

# %%
#Selecting Subsets of Rows and Columns

# %%
sh2
# Out:
#           Name  Age    City   Salary  Genger
# 0       shivam   18   delhi   200000    male
# 1       sujeet   16  Mumbai  1000000    male
# 2  khemraj sir   40     Goa    25000    male
# 3      vineeta   36   Dubai    30000  female

# %%
sh2.loc[[2,3]][['Name','Salary']]
# Out:
#           Name  Salary
# 2  khemraj sir   25000
# 3      vineeta   30000

# %%
sh2.loc[[0,2]][['City','Genger']]
# Out:
#     City Genger
# 0  delhi   male
# 2    Goa   male

# %%
#Conditional Selection

# %%
sh2
# Out:
#           Name  Age    City   Salary  Genger
# 0       shivam   18   delhi   200000    male
# 1       sujeet   16  Mumbai  1000000    male
# 2  khemraj sir   40     Goa    25000    male
# 3      vineeta   36   Dubai    30000  female

# %%
sh2[sh2["Age"] > 20]
# Out:
#           Name  Age   City  Salary  Genger
# 2  khemraj sir   40    Goa   25000    male
# 3      vineeta   36  Dubai   30000  female

# %%
sh2[sh2["Salary"] > 100000]
# Out:
#      Name  Age    City   Salary Genger
# 0  shivam   18   delhi   200000   male
# 1  sujeet   16  Mumbai  1000000   male
